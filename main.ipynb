# %%
from pybaseball import statcast
from pybaseball import statcast_batter
from pybaseball import playerid_lookup
import pandas as pd

# %%
start_dt = '2022-09-01'
end_dt = '2022-09-30'
team = 'TOR'

# %%
output = statcast(start_dt, end_dt, team)
output.to_csv('Pitching.csv', index = False)
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 30/30 [00:04<00:00,  6.65it/s]

# %%
bichette = playerid_lookup('bichette','bo', fuzzy = True)
# Out:
# Gathering player lookup table. This may take a moment.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bichette = playerid_lookup('bichette','bo', fuzzy = True)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\playerid_lookup.py:175, in playerid_lookup(last, first, fuzzy)
#     164 def playerid_lookup(last: str, first: str = None, fuzzy: bool = False) -> pd.DataFrame:
#     165     """Lookup playerIDs (MLB AM, bbref, retrosheet, FG) for a given player
#     166
#     167     Args:
#    (...)
#     173         pd.DataFrame: DataFrame of playerIDs, name, years played
#     174     """
# --> 175     client = _get_client()
#     176     return client.search(last, first, fuzzy)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\playerid_lookup.py:161, in _get_client()
#     159 global _client
#     160 if _client is None:
# --> 161     _client = _PlayerSearchClient()
#     162 return _client
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\playerid_lookup.py:79, in _PlayerSearchClient.__init__(self)
#      78 def __init__(self) -> None:
# ---> 79     self.table = get_lookup_table()
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\playerid_lookup.py:52, in get_lookup_table(save)
#      51 def get_lookup_table(save=False):
# ---> 52     table = chadwick_register(save)
#      53     # make these lowercase to avoid capitalization mistakes when searching
#      54     table['name_last'] = table['name_last'].str.lower()
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\cache\cache.py:58, in df_cache.__call__.<locals>._cached(*args, **kwargs)
#      55 result = self._safe_load_func_cache(func_data)
#      57 if result is None:
# ---> 58     result = func(*args, **kwargs)
#      59     if len(result) > 0:
#      60         self._safe_save_func_cache(func_data, result)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pybaseball\playerid_lookup.py:33, in chadwick_register(save)
#      31 mlb_only_cols = ['key_retro', 'key_bbref', 'key_fangraphs', 'mlb_played_first', 'mlb_played_last']
#      32 cols_to_keep = ['name_last', 'name_first', 'key_mlbam'] + mlb_only_cols
# ---> 33 table = pd.read_csv(io.StringIO(s.decode('utf-8')), usecols=cols_to_keep)
#      35 table.dropna(how='all', subset=mlb_only_cols, inplace=True)  # Keep only the major league rows
#      36 table.reset_index(inplace=True, drop=True)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:135, in CParserWrapper.__init__(self, src, **kwds)
#     131 assert self.orig_names is not None
#     132 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     133     self.orig_names
#     134 ):
# --> 135     self._validate_usecols_names(usecols, self.orig_names)
#     137 # error: Cannot determine type of 'names'
#     138 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     139     # error: Cannot determine type of 'names'
#
# File c:\Users\John Lee\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\base_parser.py:917, in ParserBase._validate_usecols_names(self, usecols, names)
#     915 missing = [c for c in usecols if c not in names]
#     916 if len(missing) > 0:
# --> 917     raise ValueError(
#     918         f"Usecols do not match columns, columns expected but not found: "
#     919         f"{missing}"
#     920     )
#     922 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['key_bbref', 'name_first', 'key_mlbam', 'mlb_played_last', 'key_retro', 'name_last', 'mlb_played_first', 'key_fangraphs']

# %%
print("Messing around with github")
# Out:
# Messing around with github
